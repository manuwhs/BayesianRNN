# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import time
import sys
import numpy as np
import tensorflow as tf
import reader
import util
import ptb_word_lm_tb

from tensorflow.python.client import device_lib

# %%
ptb_word_lm_tb.main(_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-779af8e7fb7e> in <module>()
# ----> 1 ptb_word_lm_tb.main(_)
#
# C:\Users\snook\Dropbox\DTU_MMC\02456 - Deep Learning\Github repos\deeplearningproject\rnn_model_TFlowTutorial\ptb\ptb_word_lm_tb.py in main(_)
#     484       valid_input = PTBInput(config=config, data=valid_data, name="ValidInput")
#     485       with tf.variable_scope("Model", reuse=True, initializer=initializer):
# --> 486         mvalid = PTBModel(is_training=False, config=config, input_=valid_input)
#     487       tf.summary.scalar("Validation_Loss", mvalid.cost)
#     488
#
# C:\Users\snook\Dropbox\DTU_MMC\02456 - Deep Learning\Github repos\deeplearningproject\rnn_model_TFlowTutorial\ptb\ptb_word_lm_tb.py in __init__(self, is_training, config, input_)
#     136       inputs = tf.nn.dropout(inputs, config.keep_prob)
#     137
# --> 138     output, state = self._build_rnn_graph(inputs, config, is_training)
#     139
#     140     softmax_w = tf.get_variable(
#
# C:\Users\snook\Dropbox\DTU_MMC\02456 - Deep Learning\Github repos\deeplearningproject\rnn_model_TFlowTutorial\ptb\ptb_word_lm_tb.py in _build_rnn_graph(self, inputs, config, is_training)
#     177       return self._build_rnn_graph_cudnn(inputs, config, is_training)
#     178     else:
# --> 179       return self._build_rnn_graph_lstm(inputs, config, is_training)
#     180
#     181   def _build_rnn_graph_cudnn(self, inputs, config, is_training):
#
# C:\Users\snook\Dropbox\DTU_MMC\02456 - Deep Learning\Github repos\deeplearningproject\rnn_model_TFlowTutorial\ptb\ptb_word_lm_tb.py in _build_rnn_graph_lstm(self, inputs, config, is_training)
#     241       for time_step in range(self.num_steps):
#     242         if time_step > 0: tf.get_variable_scope().reuse_variables()
# --> 243         (cell_output, state) = cell(inputs[:, time_step, :], state)
#     244         outputs.append(cell_output)
#     245     output = tf.reshape(tf.concat(outputs, 1), [-1, config.hidden_size])
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     178       with vs.variable_scope(vs.get_variable_scope(),
#     179                              custom_getter=self._rnn_get_variable):
# --> 180         return super(RNNCell, self).__call__(inputs, state)
#     181
#     182   def _rnn_get_variable(self, getter, *args, **kwargs):
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\layers\base.py in __call__(self, inputs, *args, **kwargs)
#     448         # Check input assumptions set after layer building, e.g. input shape.
#     449         self._assert_input_compatibility(inputs)
# --> 450         outputs = self.call(inputs, *args, **kwargs)
#     451
#     452         # Apply activity regularization.
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in call(self, inputs, state)
#     936                                       [-1, cell.state_size])
#     937           cur_state_pos += cell.state_size
# --> 938         cur_inp, new_state = cell(cur_inp, cur_state)
#     939         new_states.append(new_state)
#     940
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in __call__(self, inputs, state, scope)
#     178       with vs.variable_scope(vs.get_variable_scope(),
#     179                              custom_getter=self._rnn_get_variable):
# --> 180         return super(RNNCell, self).__call__(inputs, state)
#     181
#     182   def _rnn_get_variable(self, getter, *args, **kwargs):
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\layers\base.py in __call__(self, inputs, *args, **kwargs)
#     448         # Check input assumptions set after layer building, e.g. input shape.
#     449         self._assert_input_compatibility(inputs)
# --> 450         outputs = self.call(inputs, *args, **kwargs)
#     451
#     452         # Apply activity regularization.
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in call(self, inputs, state)
#     405
#     406     new_c = (
# --> 407         c * sigmoid(f + self._forget_bias) + sigmoid(i) * self._activation(j))
#     408     new_h = self._activation(new_c) * sigmoid(o)
#     409
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in sigmoid(x, name)
#    2051   with ops.name_scope(name, "Sigmoid", [x]) as name:
#    2052     x = ops.convert_to_tensor(x, name="x")
# -> 2053     return gen_math_ops._sigmoid(x, name=name)
#    2054
#    2055
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in _sigmoid(x, name)
#    2270     A `Tensor`. Has the same type as `x`.
#    2271   """
# -> 2272   result = _op_def_lib.apply_op("Sigmoid", x=x, name=name)
#    2273   return result
#    2274
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     765         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     766                          input_types=input_types, attrs=attr_protos,
# --> 767                          op_def=op_def)
#     768         if output_structure:
#     769           outputs = op.outputs
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2630                     original_op=self._default_original_op, op_def=op_def)
#    2631     if compute_shapes:
# -> 2632       set_shapes_for_outputs(ret)
#    2633     self._add_op(ret)
#    2634     self._record_op_seen_by_control_dependencies(ret)
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in set_shapes_for_outputs(op)
#    1909       shape_func = _call_cpp_shape_fn_and_require_op
#    1910
# -> 1911   shapes = shape_func(op)
#    1912   if shapes is None:
#    1913     raise RuntimeError(
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in call_with_requiring(op)
#    1859
#    1860   def call_with_requiring(op):
# -> 1861     return call_cpp_shape_fn(op, require_shape_fn=True)
#    1862
#    1863   _call_cpp_shape_fn_and_require_op = call_with_requiring
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\common_shapes.py in call_cpp_shape_fn(op, require_shape_fn)
#     593     res = _call_cpp_shape_fn_impl(op, input_tensors_needed,
#     594                                   input_tensors_as_shapes_needed,
# --> 595                                   require_shape_fn)
#     596     if not isinstance(res, dict):
#     597       # Handles the case where _call_cpp_shape_fn_impl calls unknown_shape(op).
#
# D:\Anaconda3\lib\site-packages\tensorflow\python\framework\common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     652       output = pywrap_tensorflow.RunCppShapeInference(
#     653           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 654           input_tensors_as_shapes, status)
#     655   except errors.InvalidArgumentError as err:
#     656     if err.message.startswith("No shape inference function exists for op"):
#
# KeyboardInterrupt:
