# %%
import brnn_model

# %%
# Model can be "test", "small", "medium", "large"
model = "small"

#Put the path to the data here
data_path = "../data"

#Put the path to where you want to save the training data
save_path = "tensorboard/"

# The mixing degree for the prior gaussian mixture
# As in Fortunato they report scanning
# mix_pi \in { 1/4, 1/2, 3/4 }
mix_pi = 0.25

# As in Fortunato they report scanning
# log sigma1 \in { 0, -1, -2 }
# log sigma2 \in { -6, -7, -8 }
log_sigma1 = -1.0
log_sigma2 = -7.0

# %%
brnn_model.main(model_select = model,
                   dat_path = data_path,
                   sav_path = save_path,
                   mixing_pi = mix_pi,
                   prior_log_sigma1 = log_sigma1,
                   prior_log_sigma2 = log_sigma2)
# Out:
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:Model/global_step/sec: 0
# Epoch: 1 Learning rate: 1.000
# INFO:tensorflow:Recording summary at step 0.
# 0.000 perplexity: 10303.343 speed: 372 wps
# KL is 126.19664764404297
# 0.004 perplexity: 7405.880 speed: 932 wps
# KL is 126.2242202758789
# 0.104 perplexity: 930.857 speed: 1294 wps
# KL is 126.09849548339844
# INFO:tensorflow:Model/global_step/sec: 3.26631
# INFO:tensorflow:Recording summary at step 392.
# 0.204 perplexity: 689.785 speed: 1310 wps
# KL is 125.8438949584961
# 0.304 perplexity: 563.164 speed: 1311 wps
# KL is 125.51109313964844
# INFO:tensorflow:Model/global_step/sec: 3.28398
# INFO:tensorflow:Recording summary at step 787.
# 0.404 perplexity: 489.096 speed: 1303 wps
# KL is 125.34840393066406
# INFO:tensorflow:Model/global_step/sec: 3.16411
# INFO:tensorflow:Recording summary at step 1167.
# 0.504 perplexity: 439.677 speed: 1296 wps
# KL is 125.11690521240234
# 0.604 perplexity: 398.001 speed: 1298 wps
# KL is 124.86351013183594
# INFO:tensorflow:Model/global_step/sec: 3.25987
# INFO:tensorflow:Recording summary at step 1558.
# 0.703 perplexity: 368.451 speed: 1298 wps
# KL is 124.6553955078125
# 0.803 perplexity: 344.931 speed: 1299 wps
# KL is 124.38883209228516
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Model/global_step/sec: 3.26697
# INFO:tensorflow:Recording summary at step 1950.
# 0.903 perplexity: 324.112 speed: 1298 wps
# KL is 124.13675689697266
# Epoch: 1 Train Perplexity: 308.239
# INFO:tensorflow:Model/global_step/sec: 3.11629
# INFO:tensorflow:Recording summary at step 2323.
# Epoch: 1 Valid Perplexity: 199.144
# Epoch: 2 Learning rate: 1.000
# 0.000 perplexity: 257.939 speed: 1319 wps
# KL is 123.96033477783203
# 0.004 perplexity: 229.284 speed: 1321 wps
# KL is 123.90054321289062
# 0.104 perplexity: 175.920 speed: 1310 wps
# KL is 123.57673645019531
# INFO:tensorflow:Model/global_step/sec: 3.1264
# INFO:tensorflow:Recording summary at step 2698.
# 0.204 perplexity: 184.882 speed: 1308 wps
# KL is 123.34464263916016
# 0.304 perplexity: 180.238 speed: 1307 wps
# KL is 123.11180877685547
# INFO:tensorflow:Model/global_step/sec: 3.25792
# INFO:tensorflow:Recording summary at step 3090.
# 0.404 perplexity: 178.709 speed: 1306 wps
# KL is 122.83779907226562
# INFO:tensorflow:Model/global_step/sec: 3.25009
# INFO:tensorflow:Recording summary at step 3479.
# 0.504 perplexity: 175.948 speed: 1304 wps
# KL is 122.55115509033203
# 0.604 perplexity: 171.744 speed: 1300 wps
# KL is 122.31541442871094
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 3864.
# 0.703 perplexity: 169.210 speed: 1294 wps
# KL is 122.03946685791016
# 0.803 perplexity: 166.661 speed: 1292 wps
# KL is 121.78191375732422
# INFO:tensorflow:Recording summary at step 4243.
# 0.903 perplexity: 163.086 speed: 1291 wps
# KL is 121.51046752929688
# INFO:tensorflow:Recording summary at step 4627.
# Epoch: 2 Train Perplexity: 161.142
# Epoch: 2 Valid Perplexity: 160.498
# Epoch: 3 Learning rate: 1.000
# 0.000 perplexity: 170.940 speed: 1319 wps
# KL is 121.24977111816406
# 0.004 perplexity: 145.904 speed: 1281 wps
# KL is 121.25548553466797
# 0.104 perplexity: 129.589 speed: 1278 wps
# KL is 120.99026489257812
# INFO:tensorflow:Recording summary at step 4977.
# 0.204 perplexity: 140.712 speed: 1276 wps
# KL is 120.63570404052734
# 0.304 perplexity: 137.732 speed: 1278 wps
# KL is 120.38421630859375
# INFO:tensorflow:Recording summary at step 5360.
# 0.404 perplexity: 138.070 speed: 1278 wps
# KL is 120.10771942138672
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 5744.
# 0.504 perplexity: 136.718 speed: 1275 wps
# KL is 119.86238861083984
# 0.604 perplexity: 134.487 speed: 1275 wps
# KL is 119.56561279296875
# INFO:tensorflow:Recording summary at step 6124.
# 0.703 perplexity: 133.644 speed: 1275 wps
# KL is 119.25212860107422
# INFO:tensorflow:Recording summary at step 6501.
# 0.803 perplexity: 132.581 speed: 1271 wps
# KL is 118.97598266601562
# 0.903 perplexity: 130.275 speed: 1272 wps
# KL is 118.6357650756836
# INFO:tensorflow:Recording summary at step 6884.
# Epoch: 3 Train Perplexity: 129.710
# Epoch: 3 Valid Perplexity: 142.517
# Epoch: 4 Learning rate: 1.000
# 0.000 perplexity: 109.281 speed: 1279 wps
# KL is 118.41939544677734
# 0.004 perplexity: 113.590 speed: 1286 wps
# KL is 118.35755920410156
# 0.104 perplexity: 109.717 speed: 1278 wps
# KL is 118.1291275024414
# INFO:tensorflow:Recording summary at step 7234.
# 0.204 perplexity: 120.227 speed: 1276 wps
# KL is 117.81470489501953
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 7616.
# 0.304 perplexity: 117.529 speed: 1268 wps
# KL is 117.5611572265625
# 0.404 perplexity: 118.218 speed: 1271 wps
# KL is 117.24445343017578
# INFO:tensorflow:Recording summary at step 7995.
# 0.504 perplexity: 117.626 speed: 1272 wps
# KL is 116.94816589355469
# 0.604 perplexity: 115.985 speed: 1273 wps
# KL is 116.66915130615234
# INFO:tensorflow:Recording summary at step 8378.
# 0.703 perplexity: 115.906 speed: 1274 wps
# KL is 116.3948745727539
# INFO:tensorflow:Recording summary at step 8761.
# 0.803 perplexity: 115.161 speed: 1274 wps
# KL is 116.1198501586914
# 0.903 perplexity: 113.390 speed: 1274 wps
# KL is 115.88461303710938
# INFO:tensorflow:Recording summary at step 9143.
# Epoch: 4 Train Perplexity: 113.260
# Epoch: 4 Valid Perplexity: 136.311
# Epoch: 5 Learning rate: 0.500
# 0.000 perplexity: 150.846 speed: 1348 wps
# KL is 115.60729217529297
# 0.004 perplexity: 101.875 speed: 1324 wps
# KL is 115.54397583007812
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 9502.
# 0.104 perplexity: 94.574 speed: 1296 wps
# KL is 115.280517578125
# 0.204 perplexity: 102.069 speed: 1301 wps
# KL is 115.03146362304688
# INFO:tensorflow:Recording summary at step 9890.
# 0.304 perplexity: 98.659 speed: 1303 wps
# KL is 114.85875701904297
# 0.404 perplexity: 98.379 speed: 1306 wps
# KL is 114.66446685791016
# INFO:tensorflow:Recording summary at step 10284.
# 0.504 perplexity: 97.262 speed: 1306 wps
# KL is 114.5458755493164
# INFO:tensorflow:Recording summary at step 10677.
# 0.604 perplexity: 95.256 speed: 1307 wps
# KL is 114.26718139648438
# 0.703 perplexity: 94.755 speed: 1308 wps
# KL is 114.15515899658203
# INFO:tensorflow:Recording summary at step 11070.
# 0.803 perplexity: 93.565 speed: 1307 wps
# KL is 113.95849609375
# 0.903 perplexity: 91.658 speed: 1308 wps
# KL is 113.80117797851562
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 11464.
# Epoch: 5 Train Perplexity: 91.194
# Epoch: 5 Valid Perplexity: 114.115
# Epoch: 6 Learning rate: 0.250
# 0.000 perplexity: 93.742 speed: 1357 wps
# KL is 113.70187377929688
# 0.004 perplexity: 86.985 speed: 1327 wps
# KL is 113.65161895751953
# INFO:tensorflow:Recording summary at step 11823.
# 0.104 perplexity: 81.930 speed: 1307 wps
# KL is 113.52072143554688
# 0.204 perplexity: 88.839 speed: 1312 wps
# KL is 113.41983032226562
# INFO:tensorflow:Recording summary at step 12217.
# 0.304 perplexity: 85.881 speed: 1312 wps
# KL is 113.36840057373047
# 0.404 perplexity: 85.596 speed: 1313 wps
# KL is 113.22833251953125
# INFO:tensorflow:Recording summary at step 12612.
# 0.504 perplexity: 84.865 speed: 1313 wps
# KL is 113.15229797363281
# INFO:tensorflow:Recording summary at step 13005.
# 0.604 perplexity: 83.094 speed: 1312 wps
# KL is 113.06889343261719
# 0.703 perplexity: 82.712 speed: 1313 wps
# KL is 112.99859619140625
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 13399.
# 0.803 perplexity: 81.431 speed: 1310 wps
# KL is 112.94100952148438
# 0.903 perplexity: 79.751 speed: 1311 wps
# KL is 112.90007781982422
# INFO:tensorflow:Recording summary at step 13789.
# Epoch: 6 Train Perplexity: 79.283
# Epoch: 6 Valid Perplexity: 106.514
# Epoch: 7 Learning rate: 0.125
# 0.000 perplexity: 120.874 speed: 1299 wps
# KL is 112.75495147705078
# 0.004 perplexity: 84.545 speed: 1306 wps
# KL is 112.77021789550781
# INFO:tensorflow:Recording summary at step 14152.
# 0.104 perplexity: 75.847 speed: 1313 wps
# KL is 112.7483901977539
# 0.204 perplexity: 82.154 speed: 1314 wps
# KL is 112.71969604492188
# INFO:tensorflow:Recording summary at step 14546.
# 0.304 perplexity: 79.563 speed: 1314 wps
# KL is 112.63053894042969
# 0.404 perplexity: 79.323 speed: 1314 wps
# KL is 112.57112121582031
# INFO:tensorflow:Recording summary at step 14940.
# 0.504 perplexity: 78.712 speed: 1314 wps
# KL is 112.5164794921875
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 15334.
# 0.604 perplexity: 76.945 speed: 1312 wps
# KL is 112.45634460449219
# 0.703 perplexity: 76.723 speed: 1311 wps
# KL is 112.43023681640625
# INFO:tensorflow:Recording summary at step 15724.
# 0.803 perplexity: 75.389 speed: 1310 wps
# KL is 112.40133666992188
# 0.903 perplexity: 73.795 speed: 1311 wps
# KL is 112.39677429199219
# INFO:tensorflow:Recording summary at step 16118.
# Epoch: 7 Train Perplexity: 73.399
# Epoch: 7 Valid Perplexity: 103.113
# Epoch: 8 Learning rate: 0.062
# 0.000 perplexity: 96.775 speed: 1355 wps
# KL is 112.42206573486328
# 0.004 perplexity: 79.670 speed: 1323 wps
# KL is 112.35865020751953
# INFO:tensorflow:Recording summary at step 16481.
# 0.104 perplexity: 73.191 speed: 1313 wps
# KL is 112.24776458740234
# 0.204 perplexity: 78.463 speed: 1312 wps
# KL is 112.27889251708984
# INFO:tensorflow:Recording summary at step 16875.
# 0.304 perplexity: 76.021 speed: 1313 wps
# KL is 112.30350494384766
# 0.404 perplexity: 75.919 speed: 1312 wps
# KL is 112.2843246459961
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 17268.
# 0.504 perplexity: 75.413 speed: 1309 wps
# KL is 112.2178726196289
# INFO:tensorflow:Recording summary at step 17660.
# 0.604 perplexity: 73.737 speed: 1310 wps
# KL is 112.21929931640625
# 0.703 perplexity: 73.580 speed: 1311 wps
# KL is 112.21955871582031
# INFO:tensorflow:Recording summary at step 18054.
# 0.803 perplexity: 72.216 speed: 1311 wps
# KL is 112.1158676147461
# 0.903 perplexity: 70.667 speed: 1311 wps
# KL is 112.16486358642578
# INFO:tensorflow:Recording summary at step 18447.
# Epoch: 8 Train Perplexity: 70.343
# Epoch: 8 Valid Perplexity: 101.453
# Epoch: 9 Learning rate: 0.031
# 0.000 perplexity: 85.568 speed: 1348 wps
# KL is 112.09723663330078
# 0.004 perplexity: 70.133 speed: 1321 wps
# KL is 112.11056518554688
# INFO:tensorflow:Recording summary at step 18806.
# 0.104 perplexity: 71.239 speed: 1297 wps
# KL is 112.17948150634766
# 0.204 perplexity: 76.305 speed: 1305 wps
# KL is 112.07591247558594
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 19200.
# 0.304 perplexity: 74.281 speed: 1301 wps
# KL is 112.11319732666016
# 0.404 perplexity: 74.066 speed: 1303 wps
# KL is 112.0191421508789
# INFO:tensorflow:Recording summary at step 19589.
# 0.504 perplexity: 73.661 speed: 1304 wps
# KL is 112.1416015625
# INFO:tensorflow:Recording summary at step 19982.
# 0.604 perplexity: 72.066 speed: 1305 wps
# KL is 112.11520385742188
# 0.703 perplexity: 71.933 speed: 1305 wps
# KL is 112.0910415649414
# INFO:tensorflow:Recording summary at step 20374.
# 0.803 perplexity: 70.533 speed: 1305 wps
# KL is 112.04840087890625
# 0.903 perplexity: 69.037 speed: 1306 wps
# KL is 112.09861755371094
# INFO:tensorflow:Recording summary at step 20767.
# Epoch: 9 Train Perplexity: 68.736
# Epoch: 9 Valid Perplexity: 100.648
# Epoch: 10 Learning rate: 0.016
# 0.000 perplexity: 95.281 speed: 1343 wps
# KL is 112.0118408203125
# 0.004 perplexity: 73.854 speed: 1317 wps
# KL is 112.05286407470703
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 21129.
# 0.104 perplexity: 70.848 speed: 1297 wps
# KL is 112.03654479980469
# 0.204 perplexity: 75.237 speed: 1303 wps
# KL is 112.07130432128906
# INFO:tensorflow:Recording summary at step 21519.
# 0.304 perplexity: 73.356 speed: 1304 wps
# KL is 112.03678131103516
# 0.404 perplexity: 73.064 speed: 1306 wps
# KL is 112.02008819580078
# INFO:tensorflow:Recording summary at step 21910.
# 0.504 perplexity: 72.729 speed: 1305 wps
# KL is 112.04093170166016
# INFO:tensorflow:Recording summary at step 22299.
# 0.604 perplexity: 71.198 speed: 1302 wps
# KL is 111.96897888183594
# 0.703 perplexity: 71.050 speed: 1303 wps
# KL is 112.03671264648438
# INFO:tensorflow:Recording summary at step 22692.
# 0.803 perplexity: 69.593 speed: 1304 wps
# KL is 112.04254913330078
# 0.903 perplexity: 68.169 speed: 1305 wps
# KL is 111.98585510253906
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 23085.
# Epoch: 10 Train Perplexity: 67.883
# Epoch: 10 Valid Perplexity: 100.142
# Epoch: 11 Learning rate: 0.008
# 0.000 perplexity: 111.106 speed: 1362 wps
# KL is 111.97270202636719
# 0.004 perplexity: 85.247 speed: 1334 wps
# KL is 111.98779296875
# INFO:tensorflow:Recording summary at step 23443.
# 0.104 perplexity: 70.910 speed: 1311 wps
# KL is 112.0111083984375
# 0.204 perplexity: 74.634 speed: 1312 wps
# KL is 111.992431640625
# INFO:tensorflow:Recording summary at step 23836.
# 0.304 perplexity: 73.048 speed: 1311 wps
# KL is 111.98111724853516
# 0.404 perplexity: 72.578 speed: 1312 wps
# KL is 111.9507064819336
# INFO:tensorflow:Recording summary at step 24230.
# 0.504 perplexity: 72.517 speed: 1312 wps
# KL is 112.02399444580078
# INFO:tensorflow:Recording summary at step 24623.
# 0.604 perplexity: 70.931 speed: 1311 wps
# KL is 111.9987564086914
# 0.703 perplexity: 70.788 speed: 1311 wps
# KL is 111.97700500488281
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 25017.
# 0.803 perplexity: 69.289 speed: 1309 wps
# KL is 112.02133178710938
# 0.903 perplexity: 67.874 speed: 1309 wps
# KL is 112.0217514038086
# INFO:tensorflow:Recording summary at step 25407.
# Epoch: 11 Train Perplexity: 67.580
# Epoch: 11 Valid Perplexity: 100.048
# Epoch: 12 Learning rate: 0.004
# 0.000 perplexity: 134.332 speed: 1352 wps
# KL is 111.91645812988281
# 0.004 perplexity: 79.610 speed: 1318 wps
# KL is 111.96659088134766
# INFO:tensorflow:Recording summary at step 25769.
# 0.104 perplexity: 70.770 speed: 1313 wps
# KL is 112.0208740234375
# 0.204 perplexity: 73.812 speed: 1312 wps
# KL is 111.9697494506836
# INFO:tensorflow:Recording summary at step 26162.
# 0.304 perplexity: 72.545 speed: 1311 wps
# KL is 111.96150970458984
# 0.404 perplexity: 72.112 speed: 1311 wps
# KL is 112.01516723632812
# INFO:tensorflow:Recording summary at step 26555.
# 0.504 perplexity: 72.095 speed: 1311 wps
# KL is 112.00321960449219
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 26949.
# 0.604 perplexity: 70.502 speed: 1310 wps
# KL is 111.93810272216797
# 0.703 perplexity: 70.351 speed: 1309 wps
# KL is 111.95941925048828
# INFO:tensorflow:Recording summary at step 27339.
# 0.803 perplexity: 68.904 speed: 1309 wps
# KL is 111.96847534179688
# 0.903 perplexity: 67.494 speed: 1310 wps
# KL is 111.99893951416016
# INFO:tensorflow:Recording summary at step 27733.
# Epoch: 12 Train Perplexity: 67.244
# Epoch: 12 Valid Perplexity: 99.937
# Epoch: 13 Learning rate: 0.002
# 0.000 perplexity: 59.048 speed: 1366 wps
# KL is 111.99321746826172
# 0.004 perplexity: 69.361 speed: 1323 wps
# KL is 111.94559478759766
# INFO:tensorflow:Recording summary at step 28095.
# 0.104 perplexity: 70.760 speed: 1309 wps
# KL is 111.97584533691406
# 0.204 perplexity: 73.470 speed: 1298 wps
# KL is 111.99909210205078
# INFO:tensorflow:Recording summary at step 28483.
# 0.304 perplexity: 72.482 speed: 1301 wps
# KL is 111.97335815429688
# 0.404 perplexity: 71.983 speed: 1303 wps
# KL is 112.02078247070312
# INFO:tensorflow:Saving checkpoint to path tensorboard/model.ckpt
# INFO:tensorflow:Recording summary at step 28876.
# 0.504 perplexity: 71.950 speed: 1301 wps
# KL is 112.0197525024414
# INFO:tensorflow:Recording summary at step 29265.
# 0.604 perplexity: 70.406 speed: 1301 wps
# KL is 111.98536682128906
# 0.703 perplexity: 70.214 speed: 1303 wps
# KL is 112.01490783691406
# INFO:tensorflow:Recording summary at step 29658.
# 0.803 perplexity: 68.808 speed: 1304 wps
# KL is 112.01810455322266
# 0.903 perplexity: 67.339 speed: 1305 wps
# KL is 111.92523193359375
# INFO:tensorflow:Recording summary at step 30051.
# Epoch: 13 Train Perplexity: 67.115
# Epoch: 13 Valid Perplexity: 99.809
# INFO:tensorflow:Recording summary at step 30199.
# Test Perplexity: 96.580
# Saving model to tensorboard/.
